# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianMejia6/IA_2025/blob/main/IAs_fracasando.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
archivo = pd.read_excel("/content/IAs fracasando.xlsx")
archivo.head()
# Out:
#   Unnamed: 0  GROUND TRUE  CHATGPT  CLAUDE  COPILOT  GROK DEEPSEEK  GEMINI  \
# 0         ia         49.0     68.0    43.0     45.0   NaN      NaN     NaN
# 1          a          NaN      NaN    44.0     30.0   NaN      NaN     NaN
# 2  académica          4.0     18.0    16.0      NaN   NaN      NaN     NaN
# 3  académica          NaN      NaN     NaN      NaN   NaN      NaN     NaN
# 4     acceso          7.0     10.0     NaN      NaN   NaN      NaN     NaN
#
#    SPACY
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
