# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianMejia6/IA_2025/blob/main/UlibroFotos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![1000469910.jpg](data:image/jpeg;base64,...)![1000475200.jpg](data:image/jpeg;base64,...)![1000484343.jpg](data:image/jpeg;base64,...)![1000484344.jpg](data:image/jpeg;base64,...)
