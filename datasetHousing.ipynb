# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianMejia6/IA_2025/blob/main/datasetHousing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/housing.csv")
data = data[data["total_bedrooms"] <= 4]
data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 73       -122.29     37.81                46.0         12.0             4.0
# 3125     -117.76     35.22                 4.0         18.0             3.0
# 3126     -117.79     35.21                 4.0          2.0             2.0
# 12286    -116.95     33.86                 1.0          6.0             2.0
# 12458    -114.62     33.62                26.0         18.0             3.0
#
#        population  households  median_income  median_house_value  \
# 73           18.0         7.0         0.4999             67500.0
# 3125          8.0         6.0         1.6250            275000.0
# 3126          6.0         2.0         2.3750            137500.0
# 12286         8.0         2.0         1.6250             55000.0
# 12458         5.0         3.0         0.5360            275000.0
#
#       ocean_proximity
# 73           NEAR BAY
# 3125           INLAND
# 3126           INLAND
# 12286          INLAND
# ...

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
model = LinearRegression()
X = data["total_bedrooms"].values.reshape(-1, 1)
Y = data["median_house_value"]
model.fit(X,Y)

y_pred=model.predict(X)

r2=r2_score(Y,y_pred)
print(f"R2 score: {r2}")
# Out:
# R2 score: 0.0789479425231856

# %%
X = data["total_bedrooms"].values.reshape(-1, 1)
Y = data["median_house_value"]

plt.figure(figsize=[10,6])
plt.scatter(X, Y, color = "green",label="Datos Reales")
plt.plot(X, y_pred,color="blue",linewidth=2,label="Regresión lineal")
plt.xlabel("Cantidad de habitaciones")
plt.ylabel("Precio medio")
plt.title("Cantidad de habitaciones vs Precio medio")
plt.legend()
plt.grid(True)
plt.show()

print(f"Ecuacion de la recta y= {model.coef_[0]:.2f}x+ {model.intercept_:.2f}")
print(f"Coeficiente de Determionacion: {r2:.2f}")
# Out:
# Ecuacion de la recta y= -46129.15x+ 375780.06
# Coeficiente de Determionacion: 0.08

# %% [markdown]
# y=m⋅x+b
#
# y=−46129.15x+375780.06
#
# y=−184516.6+375780.06=191263.46
